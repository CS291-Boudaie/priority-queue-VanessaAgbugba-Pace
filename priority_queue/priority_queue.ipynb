# %%
from priority_queue import MinHeap, PriorityQueue

# %%
mh = MinHeap()
mh.add(10, "A")
mh.add(5, "B")
mh.add(8, "C")

print(mh.peek())  

q = PriorityQueue()
q.push("apple", 3)
q.push("banana", 1)
q.push("cherry", 2)

print(q.pop())  
print(q.peek())
# Out:
# (5, 'B')
# banana
# cherry
